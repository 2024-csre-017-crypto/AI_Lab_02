# %%
#-----Task 4:simple login(3 attempts)----
#Hard-codded demo  credentials
CORRECT_USER="admin"
CORRECT_PASS="1234"

attempts=3

while attempts>0:
    u=input("Username:")
    p=input("Password:")

    if u==CORRECT_USER and p==CORRECT_PASS:
        print("Login Successful")
        break
    else:
        attempts-=1
        print("Invalid Credentials.Attempts left:",attempt)
if attempts==0:
    print("Account Locked(demo).Please try later.")
# Out:
# Username: admin
# Password: 1234
# Login Successful
