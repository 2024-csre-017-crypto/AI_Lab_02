# %%
#-------Task 5:Multiplication table of 1-10
num=int(input("Enter a number:"))

for i in range(1,11):
    print(f"{num}X{i}={num*i}")
# Out:
# Enter a number: 5
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
# 5X10=50
